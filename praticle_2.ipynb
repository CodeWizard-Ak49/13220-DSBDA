# %%
AIM: To learn
   1. Creation of Dataset using Microsoft Excel.
   2. Identification and Handling of Null Values
   3. Identification and Handling of Outliers
   4. Data Transformation for the purpose of:
      a. To change the scale for better understanding
      b. To decrease the skewness and convert distribution into normal distribution

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:/Users/Admin/OneDrive/Documents/StudentPerformance.csv")

# %%
data
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0         64.0           84.0           64.0               79          2018.0
# 1         71.0           93.0           72.0               89          2020.0
# 2         88.0           82.0           77.0               95          2019.0
# 3         62.0           81.0           60.0              100          2019.0
# 4         73.0           75.0           75.0               92          2017.0
# 5         73.0           87.0           58.0               99          2021.0
# 6         64.0           93.0            NaN               94          2021.0
# 7         74.0           80.0           61.0               80          2021.0
# 8         78.0           87.0           69.0               74          2019.0
# 9         67.0           92.0           60.0               77          2019.0
# 10        68.0           84.0           64.0               84          2020.0
# ...

# %%
#data = data.fillna(0).astype(int)

# %%
data[data.select_dtypes(include=['float']).columns] = data.select_dtypes(include=['float']).astype('Int64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Math_Score             29 non-null     Int64
#  1   Reading_Score          29 non-null     Int64
#  2   Writing_Score          29 non-null     Int64
#  3   Placement_Score        30 non-null     int64
#  4   Club_Join_Date         29 non-null     Int64
#  5   Placement_Offer_Count  30 non-null     int64
# dtypes: Int64(4), int64(2)
# memory usage: 1.7 KB

# %%
data.describe()
# Out:
#        Math_Score  Reading_Score  Writing_Score  Placement_Score  \
# count        29.0           29.0           29.0        30.000000
# mean     70.62069      85.241379       69.37931        86.800000
# std       9.12772       5.736196       8.191519         9.349166
# min          59.0           75.0           58.0        70.000000
# 25%          63.0           81.0           62.0        79.000000
# 50%          69.0           85.0           69.0        86.000000
# 75%          74.0           89.0           76.0        94.750000
# max          94.0           95.0           88.0       100.000000
#
#        Club_Join_Date  Placement_Offer_Count
# count            29.0              30.000000
# mean      2019.517241               2.433333
# std           1.29892               0.626062
# min            2017.0               1.000000
# 25%            2018.0               2.000000
# 50%            2020.0               2.500000
# 75%            2021.0               3.000000
# ...

# %%
data.isnull()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0        False          False          False            False           False
# 1        False          False          False            False           False
# 2        False          False          False            False           False
# 3        False          False          False            False           False
# 4        False          False          False            False           False
# 5        False          False          False            False           False
# 6        False          False           True            False           False
# 7        False          False          False            False           False
# 8        False          False          False            False           False
# 9        False          False          False            False           False
# 10       False          False          False            False           False
# ...

# %%
data.isnull().sum()
# Out:
# Math_Score               1
# Reading_Score            1
# Writing_Score            1
# Placement_Score          0
# Club_Join_Date           1
# Placement_Offer_Count    0
# dtype: int64

# %%
data.notnull()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0         True           True           True             True            True
# 1         True           True           True             True            True
# 2         True           True           True             True            True
# 3         True           True           True             True            True
# 4         True           True           True             True            True
# 5         True           True           True             True            True
# 6         True           True          False             True            True
# 7         True           True           True             True            True
# 8         True           True           True             True            True
# 9         True           True           True             True            True
# 10        True           True           True             True            True
# ...

# %%
data.notnull().sum()
# Out:
# Math_Score               29
# Reading_Score            29
# Writing_Score            29
# Placement_Score          30
# Club_Join_Date           29
# Placement_Offer_Count    30
# dtype: int64

# %%
data.head()
# Out:
#    Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0          64             84             64               79            2018
# 1          71             93             72               89            2020
# 2          88             82             77               95            2019
# 3          62             81             60              100            2019
# 4          73             75             75               92            2017
#
#    Placement_Offer_Count
# 0                      2
# 1                      3
# 2                      3
# 3                      3
# 4                      3

# %%
data.tail()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 25          74             85             62               80            2018
# 26          90             95             82              100            2021
# 27          69             88             70               89            2018
# 28          79             85             79               77            2018
# 29          78             82             77               75            2020
#
#     Placement_Offer_Count
# 25                      2
# 26                      3
# 27                      3
# 28                      2
# 29                      2

# %%
data.columns
# Out:
# Index(['Math_Score', 'Reading_Score', 'Writing_Score', 'Placement_Score',
#        'Club_Join_Date', 'Placement_Offer_Count'],
#       dtype='object')

# %%
print(len(data))
# Out:
# 30

# %%
data.shape
# Out:
# (30, 6)

# %%
data.size
# Out:
# 180

# %%
print(len(data.columns))
# Out:
# 6

# %%
colm=list(data.columns)

# %%
colm
# Out:
# ['Math_Score',
#  'Reading_Score',
#  'Writing_Score',
#  'Placement_Score',
#  'Club_Join_Date',
#  'Placement_Offer_Count']

# %%
print(colm)
# Out:
# ['Math_Score', 'Reading_Score', 'Writing_Score', 'Placement_Score', 'Club_Join_Date', 'Placement_Offer_Count']

# %%
data.min()
# Out:
# Math_Score                 59
# Reading_Score              75
# Writing_Score              58
# Placement_Score            70
# Club_Join_Date           2017
# Placement_Offer_Count       1
# dtype: Int64

# %%
data.max()
# Out:
# Math_Score                 94
# Reading_Score              95
# Writing_Score              88
# Placement_Score           100
# Club_Join_Date           2022
# Placement_Offer_Count       3
# dtype: Int64

# %%
data.ndim
# Out:
# 2

# %%
col =['Reading_Score', 'Reading_Score', 'Writing_Score', 'Placement_Score']
data.boxplot(col)
# Out:
# <Axes: >

# %%
series = pd.notnull(data["Math_Score"])
data[series]
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0           64             84             64               79            2018
# 1           71             93             72               89            2020
# 2           88             82             77               95            2019
# 3           62             81             60              100            2019
# 4           73             75             75               92            2017
# 5           73             87             58               99            2021
# 6           64             93           <NA>               94            2021
# 7           74             80             61               80            2021
# 8           78             87             69               74            2019
# 9           67             92             60               77            2019
# 10          68             84             64               84            2020
# ...

# %%
series = pd.isnull(data["Math_Score"])
data[series]
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 19        <NA>             87             75              100            2018
#
#     Placement_Offer_Count
# 19                      3

# %%
"""m_v=df['Reading_Score'].mean()
df['Reading_Score'].fillna(value=m_v, inplace=True)
df"""
# Out:
# "m_v=df['Reading_Score'].mean()\ndf['Reading_Score'].fillna(value=m_v, inplace=True)\ndf"

# %%
ndata=data.copy()
ndata.replace(to_replace = np.nan, value = -99)
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0           64             84             64               79            2018
# 1           71             93             72               89            2020
# 2           88             82             77               95            2019
# 3           62             81             60              100            2019
# 4           73             75             75               92            2017
# 5           73             87             58               99            2021
# 6           64             93            -99               94            2021
# 7           74             80             61               80            2021
# 8           78             87             69               74            2019
# 9           67             92             60               77            2019
# 10          68             84             64               84            2020
# ...

# %%
sorted_rscore= sorted(data['Reading_Score'].dropna())
sorted_rscore
# Out:
# [75,
#  76,
#  77,
#  78,
#  79,
#  80,
#  80,
#  81,
#  82,
#  82,
#  82,
#  84,
#  84,
#  85,
#  85,
#  86,
#  87,
#  87,
#  87,
#  88,
#  88,
#  89,
#  90,
#  92,
#  92,
#  93,
#  93,
#  95,
#  95]

# %%
median=np.median(sorted_rscore)
median
# Out:
# 85.0

# %%
new_data=data.copy()
new_data['Reading_Score'].plot(kind ='hist')
data['log_math'] = np.log10(data['Reading_Score'])
plt.show()

# %%
data['log_math'].plot(kind = 'hist')
plt.show()

# %%
fig, ax =plt.subplots(figsize = (18,10))
ax.scatter(data['Reading_Score'], data['Writing_Score'])
plt.show()

# %%
1 NAME:ATHARV KOLE 
2 ROLL NO:13220
